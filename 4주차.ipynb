# %% [markdown]
# 복습문제    1.변수와 출력

# %%
x=3
y=7

print(x + y)
print(x - y)
print(x * y)
# Out:
# 10
# -4
# 21

# %% [markdown]
# 복습문제 - 리스트와 언덱스

# %%
fruits = ["apple", "banana", "pear","cherry"]
print(fruits[1])
print(len(fruits))
fruits.append("kiwi")
print(fruits)
# Out:
# banana
# 4
# ['apple', 'banana', 'pear', 'cherry', 'kiwi']

# %% [markdown]
# 복습문제 - 반복문과 조건문

# %%
scores = [11,35,20,59,90]
for score in scores:
    if score >=60:
        print(score, "합격")
    else:
        print(score, "불합격")
# Out:
# 11 불합격
# 35 불합격
# 20 불합격
# 59 불합격
# 90 합격

# %% [markdown]
# 복습문제 -함수

# %%
def calculate_average(numbers):
    total = 0
    for n in numbers:
        total += n
    return total / len(numbers)

my_scores= [ 80,90,70,100]
avg= calculate_average(my_scores)
print("평균:", avg)
# Out:
# 평균: 85.0

# %% [markdown]
# 복습문제 - 종합
#
#
#    ex)  로그출력
#
#     -A학생은A등급입니다
#
#     -B학생은C등급입니다
#
#     -C학생은B등급입니다

# %%
scores  = ["D","F","E"]
scorew = [72,94,23]


def num(scorew):
        if num <= 80:
            print("A")
        elif num <= 70:
            print("B")
        else :
            print("C")

# %%
students = ["A", "B", "C"] 
student_scores = [95,58,72]
                                                                                                                                                                                                                   
def total(score):
    if score >= 80:
        return "A"
    elif score >= 70:                                              
        return "B"
    else:
        return "C"

for i in range(len(student_scores)):
      num = total(student_scores[i])
      print(f"{students[i]}학생은 {num}등급입니다")
# Out:
# A학생은 A등급입니다
# B학생은 C등급입니다
# C학생은 B등급입니다

# %% [markdown]
# # 머신러닝
#
#   정의: 사람이 규착을 직접 생성하는대신,
#   데이터를 보고 컴퓨터가 스스로 규칙을 찾아내는 방법
#
#
#   일반 프로그래밍 vs 머신러닝
#
#  | 구분 |                  일반프로그래밍                   |           머신러닝         |
#  |   ---   |    ---                                       |   ---                           |
#  |  규칙을 누가 만드나 |  사람                          |   컴퓨터가 데이터에 찾는다        |
#  |    필요한 것     |       규칙(IF문 등)             |     데이터+정답                               |
#  |    예시         |      if 점수 >= 60 : 합격           |            과거 데이터를 참조. 기준을 찾게함                      |
#  |    장점          |   규칙이 적거나, 명확할떄 좋음                      |          규칙이 복잡할떄 좋음                              |

# %% [markdown]
# |
# # 시작하기

# %% [markdown]
# ## 라이브러리 설치
#
#   - pandas: 표(DateFrame) 형태로 데이터를 다루는 도구
#   - scikit-learn: 머신러닝 모델을 쉽게 만들 수 있는 도구

# %%
# %pip install pandas scikit-learn
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------- ----------------- 5.5/9.9 MB 28.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 29.5 MB/s  0:00:00
# Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------------------------- ---------- 6.0/8.1 MB 30.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 29.4 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading numpy-2.4.4-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------- ----------------- 7.1/12.4 MB 35.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 33.4 MB/s  0:00:00
# Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ------- -------------------------------- 7.3/37.3 MB 36.2 MB/s eta 0:00:01
#    --------------- ------------------------ 14.4/37.3 MB 35.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 21.0/37.3 MB 35.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 21.2/37.3 MB 30.0 MB/s eta 0:00:01
#    ------------------------- -------------- 24.1/37.3 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.0/37.3 MB 25.5 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 25.8 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 25.0 MB/s  0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, threadpoolctl, numpy, joblib, scipy, pandas, scikit-learn
#
#    ---------------------------------------- 0/7 [tzdata]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------- ---------------------------- 2/7 [numpy]
#    ----------------- ---------------------- 3/7 [joblib]
#    ----------------- ---------------------- 3/7 [joblib]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------- ----------------- 4/7 [scipy]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------- ----------- 5/7 [pandas]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------- ----- 6/7 [scikit-learn]
#    ---------------------------------------- 7/7 [scikit-learn]
#
# Successfully installed joblib-1.5.3 numpy-2.4.4 pandas-3.0.2 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0 tzdata-2026.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier

print("라이브러 불러오기 완료")
# Out:
# 라이브러 불러오기 완료

# %% [markdown]
# ## 데이터 준비: 표 (DateFrame)만들기
#
# 가상의 학생 데이터 만들기
# - `study_hours`: 주당 공부 시간
# - `attendance`:  출석율(%)
# - `pass_fail` :  합격 여부 (1=합격, 0=불합격)

# %%
# 딕셔너리로 데이터 만들기
# 딕셔너리는 {key : value } 형태

data = {
         "study_hours": [1,2,3,3,4,4,5,6,7,8],
         "attendance": [50,55,60,80,60,75,75,80,90,95],
         "pass_fail": [0,0,0,1,0,1,1,1,1,1]
}
df = pd.DataFrame(data)
df
# Out:
#    study_hours  attendance  pass_fail
# 0            1          50          0
# 1            2          55          0
# 2            3          60          0
# 3            3          80          1
# 4            4          60          0
# 5            4          75          1
# 6            5          75          1
# 7            6          80          1
# 8            7          90          1
# 9            8          95          1

# %% [markdown]
#  ## 데이터프레임 파악하기

# %%
print("-- 공부 시간만 보기 ---  ")
print(df["study_hours"])
# Out:
# -- 공부 시간만 보기 ---
# 0    1
# 1    2
# 2    3
# 3    3
# 4    4
# 5    4
# 6    5
# 7    6
# 8    7
# 9    8
# Name: study_hours, dtype: int64

# %%
print(" -- 공부 시간과  출석률 -- ")
print(df[["study_hours", "attendance"]])

# %%
# 데이터의 기본 정보 확인
print("행과 열의 수",df.shape)
print("열 이름들:",list(df.columns))

# %%
# 특정 행 하나만 보기
print("-- 1번쨰 학생 -- ")
print(df.iloc[0])
print("-- 4번째 학생 -- ")
print(df.iloc[3])
print("-- 1번쨰 학생의 출석률 -- ")
print(df.iloc[0,1])

# %%
# 기본 통제 보기

print("-- 기본 통계 -- ")
print(df.describe())

# %% [markdown]
#  | 코드 | 하는 일 | 예시 |
#  | --   | --       | --
#  |df["열이름"]      | 특정 열 전체 보기     |    df[`study_hours`] |
#  |df[["열1","열2"]] | 여러 열 보기          | df[`study_hours`,`attendance`]] |
#  |df.iloc[0]        |    특정 행 보기      | df.iloc[0]
#  |df.iloc[행,열]    | 특정 값 꺼내기        | df.iloc[0,1]->첫행의 두번쨰 값 |
#  | df .shape        | 행과 열의 수         | (10,3) |
#  |df .colums        | 열의 이름들          | [`study_hours`,`attendance`,...]  |
#  |df.describe()     | 기본 통계            | 평균,최소,최대등    |

# %% [markdown]
# # 모델 학습과 예측 실습

# %%
# 새 학생 1명을 예측 해보기
# 4시간 공부, 출석율을 80% 
# prediction 예측값
new_student = pd.DataFrame([[4,80]], columns=["study_hours", "attendance"])
prediction = model.predict(new_student)
print("공부 4시간, 출석 80% 인 학생:", prediction)


if prediction[0] == 1:
    print("모델 판단 : 합격")
else:
    print("모델 판단 : 불합격")
# Out:
# 공부 4시간, 출석 80% 인 학생: [1]
# 모델 판단 : 합격

# %%
#여러 학생 예측하기 

new_students = pd.DataFrame([
    [1,50],
    [3,65],
    [5,80],
    [7,95],
], columns=["study_hours", "attendance"])

results = model.predict(new_students)




#문제:
# 각 학생의 로그를 출력해주세요
# 예시 :
# 공부 ?시간, 출석 ?% 인 학생은 (합격/불합격)입니다.
# 공부 ?시간, 출석 ?% 인 학생은 (합격/불합격)입니다.
# 공부 ?시간, 출석 ?% 인 학생은 (합격/불합격)입니다.
# 공부 ?시간, 출석 ?% 인 학생은 (합격/불합격)입니다.

for i in range(len(new_students)):  
    study_hours = new_students.iloc[i,0]
    attendance = new_students.iloc[i,1]
 
    if results[i] == 1: 
        result = "합격"
    else:   
        result= "불합격"     
    print(f"공부 {study_hours}시간, 출석 {attendance}% 인 학생은 {result}입니다.")
# Out:
# 공부 1시간, 출석 50% 인 학생은 불합격입니다.
# 공부 3시간, 출석 65% 인 학생은 불합격입니다.
# 공부 5시간, 출석 80% 인 학생은 합격입니다.
# 공부 7시간, 출석 95% 인 학생은 합격입니다.
