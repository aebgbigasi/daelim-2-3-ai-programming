# %% [markdown]
# # 3주차

# %% [markdown]
# 파이썬 로그 출력하기

# %%
print("안녕하세요")

# %%
1+3

# %% [markdown]
# 셀 순서 중요도

# %%
x = 10
print(x)

# %%
print( x+90)

# %% [markdown]
#  변수

# %%
age = 20
score = 80

print(age)
print(score)
print(age+score)

# %% [markdown]
# 숫자와 문자열

# %%
name = "Yang"
year = 2026

print(name)
print(year)
print(type(name))
print(type(year))

# %% [markdown]
# 문자열 예시

# %%
first = "machine"
second = "learning"
print( first + " " + second)

# %%
major = "AI응용프로그래밍"

print("수업명:" +major)

# %% [markdown]
# 리스트

# %%
scores = [10,20,30,40,50]
print(scores)
print(scores[0])
print(len(score))
scores.append(60)
print(scores)
print(len(scores))

# %%
scores[5] = 100
print(scores)

# %%
scores = [60,70,80,90,100]
print(scores)

# %% [markdown]
# 반복문

# %%
for score in scores:
    print("점수:" , score)

# %% [markdown]
# 조건문

# %%
temp = -10

if temp >= 20:
    print("덥다")
elif temp >=40:
    print("죽는날씨다")
elif temp >= 10:
    print("따뜻함")
elif temp >= 0:
    print("춥다")
else:
    print("매우춥다")

# %%
number = 7
if number % 2 == 0:
    print("짝수")
else:
    print("홀수")

# %% [markdown]
# 반복문과 조건문을 함께 사용

# %%
scores = [42 ,60, 77, 89, 20]
for score in scores:
    if score >= 60:
        print(f'{score}점은 합격입니다')
    else:
        print(f'{score}점은 불합격입니다')

        #60점은 합격입니다
        # 42점은 불합격입니다

# %% [markdown]
# 함수

# %%
def greet(name):
    print(f'{name}님, 안녕하세요')   

greet("민준")

# %%
def add_numbers(a,b):
    return a + b

print(add_numbers(1, 2))

# %%
numbers = [1,2,3,4,5]
#합계: numbers를 다 더한 값
total = 0
for number in numbers:
    total += number
print("합계:",total)

# %%
scores = [65,82,91,100,58,77]
#70점 이상은 합격
#합격자는 x명 입니다
total = 0
for score in scores:    
    if score >=70 :   
        total += 1
print(f'합격자는 {total}명 입니다')

# %% [markdown]
# # 머신러닝|

# %% [markdown]
# 라이브러리 불러오기

# %%
# %pip install pandas scikit-learn

# %%
import pandas as  pd
from sklearn.tree import DecisionTreeClassifierkj
